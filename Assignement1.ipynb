# %%
import os
import numpy as np
from PIL import Image,ImageFilter
import matplotlib.pyplot as plt

# %%
for root, dirs, files in os.walk(".\\Assignment1Images\\"):
    #print(files)
    i = 0
    imagesAsArray =np.zeros((20,500, 500, 3))
    for filename in files:
        #print(i)
        if filename.endswith(".jpg"):
            #print(filename)
            im = Image.open(root+filename)
            im = im.resize((500, 500), Image.ANTIALIAS)
            #print(im)
            img = np.array(im)
            #print(type(img))
            #print(img.shape)
            imgplot = plt.imshow(img)
            plt.show()
            imagesAsArray[i] = img
            i = i+1
print(imagesAsArray)
# Out:
# [[[[ 19.  71.   5.]
#    [ 12.  45.   6.]
#    [ 33.  70.  29.]
#    ...
#    [ 10.  35. 180.]
#    [ 10.  35. 180.]
#    [ 12.  34. 179.]]
#
#   [[ 29.  95.  11.]
#    [ 17.  56.   8.]
#    [ 21.  53.  12.]
#    ...
#    [ 10.  35. 180.]
#    [ 10.  35. 179.]
#    [ 10.  35. 179.]]
#
#   [[ 36. 108.  13.]
#    [ 26.  73.  12.]
#    [ 39.  82.  18.]
#    ...
#    [  9.  35. 180.]
#    [  9.  36. 179.]
#    [ 10.  36. 179.]]
#
#   ...
#
#   [[109. 103.  91.]
#    [111. 105.  93.]
#    [110. 104.  92.]
#    ...
#    [ 21. 111. 145.]
#    [ 24. 111. 146.]
#    [ 19. 105. 140.]]
#
#   [[109. 103.  91.]
#    [110. 104.  92.]
#    [111. 105.  93.]
#    ...
#    [ 19. 109. 143.]
#    [ 19. 108. 142.]
#    [ 21. 107. 142.]]
#
#   [[109. 103.  91.]
#    [109. 103.  91.]
#    [109. 103.  91.]
#    ...
#    [ 24. 115. 149.]
#    [ 24. 114. 148.]
#    [ 23. 111. 143.]]]
#
#
#  [[[ 26. 102. 203.]
#    [ 25. 100. 201.]
#    [ 24.  98. 199.]
#    ...
#    [  0.   0.   0.]
#    [  0.   0.   0.]
#    [  0.   0.   0.]]
#
#   [[ 26. 102. 203.]
#    [ 26. 101. 202.]
#    [ 25.  99. 200.]
#    ...
#    [  0.   0.   0.]
#    [  0.   0.   0.]
#    [  0.   0.   0.]]
#
#   [[ 26. 103. 204.]
#    [ 26. 102. 203.]
#    [ 25. 100. 202.]
#    ...
#    [  0.   0.   0.]
#    [  0.   0.   0.]
#    [  0.   0.   0.]]
#
#   ...
#
#   [[ 70.  57.  40.]
#    [ 60.  48.  28.]
#    [ 50.  38.  20.]
#    ...
#    [ 11.  11.   6.]
#    [ 14.  11.   8.]
#    [ 17.  13.   9.]]
#
#   [[ 49.  39.  21.]
#    [ 57.  45.  24.]
#    [ 63.  49.  27.]
#    ...
#    [  9.   9.   6.]
#    [ 11.  10.   7.]
#    [ 14.  11.   7.]]
#
#   [[ 44.  36.  22.]
#    [ 57.  45.  28.]
#    [ 68.  54.  34.]
#    ...
#    [  7.   7.   5.]
#    [  9.   8.   6.]
#    [ 12.  10.   6.]]]
#
#
#  [[[ 97.  54.  30.]
#    [ 39.  27.   4.]
#    [ 50.  66.  14.]
#    ...
#    [ 94.  93.   8.]
#    [ 84.  71.   5.]
#    [ 77.  82.   6.]]
#
#   [[ 58.  37.  12.]
#    [ 59.  62.  14.]
#    [125. 138.  31.]
#    ...
#    [ 79.  93.   3.]
#    [ 71.  80.  10.]
#    [ 48.  62.   7.]]
#
#   [[ 46.  16.   8.]
#    [ 88.  83.  29.]
#    [184. 185.  31.]
#    ...
#    [ 73. 102.  13.]
#    [ 42.  68.   5.]
#    [ 36.  58.   3.]]
#
#   ...
#
#   [[ 32.  71.   6.]
#    [ 44.  98.   5.]
#    [ 59.  86.  10.]
#    ...
#    [ 79. 104.   2.]
#    [ 71.  87.   3.]
#    [ 50.  80.   1.]]
#
#   [[ 24.  42.   2.]
#    [ 44.  60.   3.]
#    [ 27.  45.   5.]
#    ...
#    [ 52.  86.   4.]
#    [ 62.  81.   3.]
#    [ 51.  82.   2.]]
#
#   [[ 49.  72.  11.]
#    [ 35.  41.   1.]
#    [ 18.  33.   4.]
#    ...
#    [ 50.  86.   3.]
#    [ 66.  88.   5.]
#    [ 54.  84.   4.]]]
#
#
#  ...
#
#
#  [[[165. 183. 211.]
#    [165. 189. 215.]
#    [168. 190. 212.]
#    ...
#    [224. 217. 226.]
#    [224. 217. 223.]
#    [226. 219. 227.]]
#
#   [[173. 195. 214.]
#    [178. 195. 218.]
#    [181. 196. 221.]
#    ...
#    [224. 215. 222.]
#    [226. 216. 224.]
#    [225. 214. 225.]]
#
#   [[179. 198. 222.]
#    [175. 195. 219.]
#    [176. 198. 226.]
#    ...
#    [223. 211. 217.]
#    [224. 213. 219.]
#    [225. 214. 221.]]
#
#   ...
#
#   [[164. 142. 128.]
#    [155. 136. 127.]
#    [156. 136. 126.]
#    ...
#    [ 27.  25.  18.]
#    [ 29.  25.  16.]
#    [ 27.  26.  18.]]
#
#   [[161. 138. 121.]
#    [160. 138. 127.]
#    [159. 136. 130.]
#    ...
#    [ 22.  23.  12.]
#    [ 26.  23.  10.]
#    [ 23.  21.   7.]]
#
#   [[163. 139. 125.]
#    [160. 139. 119.]
#    [158. 136. 125.]
#    ...
#    [ 17.  19.  10.]
#    [ 22.  21.  17.]
#    [ 22.  21.  19.]]]
#
#
#  [[[ 35.  34.  32.]
#    [ 35.  34.  32.]
#    [ 35.  34.  32.]
#    ...
#    [194. 182. 170.]
#    [194. 182. 171.]
#    [195. 181. 173.]]
#
#   [[ 33.  32.  31.]
#    [ 33.  32.  31.]
#    [ 33.  32.  31.]
#    ...
#    [194. 182. 171.]
#    [194. 182. 171.]
#    [194. 180. 172.]]
#
#   [[ 33.  32.  30.]
#    [ 33.  32.  30.]
#    [ 32.  31.  29.]
#    ...
#    [194. 182. 171.]
#    [194. 182. 171.]
#    [194. 181. 172.]]
#
#   ...
#
#   [[  8.  44.  61.]
#    [  9.  43.  60.]
#    [ 12.  43.  57.]
#    ...
#    [203. 210. 209.]
#    [203. 209. 209.]
#    [204. 210. 210.]]
#
#   [[  9.  45.  61.]
#    [  9.  44.  60.]
#    [ 10.  44.  59.]
#    ...
#    [203. 209. 209.]
#    [203. 209. 209.]
#    [203. 209. 209.]]
#
#   [[ 10.  46.  62.]
#    [  9.  46.  62.]
#    [  9.  45.  61.]
#    ...
#    [204. 207. 207.]
#    [203. 206. 206.]
#    [203. 206. 206.]]]
#
#
#  [[[243. 245. 242.]
#    [244. 246. 243.]
#    [243. 245. 242.]
#    ...
#    [244. 245. 247.]
#    [244. 245. 247.]
#    [244. 245. 247.]]
#
#   [[243. 245. 242.]
#    [244. 246. 243.]
#    [243. 245. 242.]
#    ...
#    [244. 245. 247.]
#    [244. 245. 247.]
#    [244. 245. 247.]]
#
#   [[243. 245. 242.]
#    [243. 245. 242.]
#    [243. 245. 242.]
#    ...
#    [244. 245. 247.]
#    [244. 245. 247.]
#    [244. 245. 247.]]
#
#   ...
#
#   [[ 18.  18.  18.]
#    [ 18.  18.  18.]
#    [ 18.  18.  18.]
#    ...
#    [ 18.  18.  18.]
#    [ 19.  19.  19.]
#    [ 19.  19.  19.]]
#
#   [[ 18.  18.  18.]
#    [ 18.  18.  18.]
#    [ 18.  18.  18.]
#    ...
#    [ 18.  18.  18.]
#    [ 18.  18.  18.]
#    [ 18.  18.  18.]]
#
#   [[ 18.  18.  18.]
#    [ 18.  18.  18.]
#    [ 18.  18.  18.]
#    ...
#    [ 18.  18.  18.]
#    [ 18.  18.  18.]
#    [ 18.  18.  18.]]]]
